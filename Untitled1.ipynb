# %%
#mutual info based feature selec

import pandas as pd
mydata = 'GSE64810'
data_file = './data/'+ mydata +'_Train.csv'
df=pd.read_csv(data_file).T

new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

df.head()
# Out:
# SID        Gene_653635 Gene_102466751 Gene_100996442 Gene_729737  \
# GSM1580869    3.306293       1.945804       2.240528    2.783362
# GSM1580870    3.343485       2.102988       2.301725    3.025018
# GSM1580871    3.004362       1.836035       2.199412    2.844297
# GSM1580872     3.16513       1.912467       2.363029    2.905897
# GSM1580873    3.138684       1.885064       2.282564    2.731643
#
# SID        Gene_102725121 Gene_102723897 Gene_102465909 Gene_107985721  \
# GSM1580869       1.435488       3.425255       1.857635       1.125694
# GSM1580870       0.527999       3.507347       1.858452       1.182904
# GSM1580871        0.49291       3.146981       1.499832       1.021182
# GSM1580872       1.225875       3.160406       1.633568       1.196748
# GSM1580873       1.285194       3.235448       1.559448       1.186558
#
# SID        Gene_112268260 Gene_100132287  ... Gene_4564 Gene_4575 Gene_4568  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(labels=['disease'], axis=1),
    df['disease'].astype('str'),
    test_size=0.3,
    random_state=0)
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X_train, y_train)

# %%
mutual_info1 = pd.Series(mutual_info)
mutual_info1.index = X_train.columns
TopMarker=mutual_info1.sort_values(ascending=False)

# %%
TopMarker[1:100].plot(kind='bar',alpha=0.75,rot=90,figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='SID'>
